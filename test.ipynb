# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential, load_model
import time

start = time.time()

#Define Path
model_path = './models/model.h5'
model_weights_path = './models/weights.h5'
test_path = 'data/test_image'

#Load the pre-trained models
model = load_model(model_path)
model.load_weights(model_weights_path)

#Define image parameters
img_width, img_height = 150, 150

#Prediction Function
def predict(file):
  x = load_img(file, target_size=(img_width,img_height))
  x = img_to_array(x)
  x = np.expand_dims(x, axis=0)
  array = model.predict(x)
  result = array[0]
  #print(result)
  answer = np.argmax(result)
  if answer == 0:
    print("Predicted: dewi")
  elif answer == 1:
    print("Predicted: hasudungan")
  elif answer == 2:
    print("Predicted: maredi")
  elif answer == 3:
    print("Predicted: mia")
  elif answer == 4:
    print("Predicted: michael")
  elif answer == 5:
    print("Predicted: parida")
  elif answer == 6:
    print("Predicted: rosari")
  elif answer == 7:
    print("Predicted: sonya")
  elif answer == 8:
    print("Predicted: tahan")
  elif answer == 9:
    print("Predicted: yustina")
  
  return answer

#Walk the directory for every image
for i, ret in enumerate(os.walk(test_path)):
  for i, filename in enumerate(ret[2]):
    if filename.startswith("."):
      continue
    
    print(ret[0] + '/' + filename)
    result = predict(ret[0] + '/' + filename)
    print(" ")

#Calculate execution time
end = time.time()
dur = end-start

if dur<60:
    print("Execution Time:",dur,"seconds")
elif dur>60 and dur<3600:
    dur=dur/60
    print("Execution Time:",dur,"minutes")
else:
    dur=dur/(60*60)
    print("Execution Time:",dur,"hours")
# Out:
# data/test_image/dewi1.bmp
# Predicted: hasudungan
#
# data/test_image/dewi2.bmp
# Predicted: hasudungan
#
# data/test_image/hasudungan1.bmp
# Predicted: hasudungan
#
# data/test_image/hasudungan2.bmp
# Predicted: mia
#
# data/test_image/maredi1.bmp
# Predicted: parida
#
# data/test_image/maredi2.bmp
# Predicted: mia
#
# data/test_image/mia1.bmp
# Predicted: mia
#
# data/test_image/mia2.bmp
# Predicted: hasudungan
#
# data/test_image/michael1.bmp
# Predicted: hasudungan
#
# data/test_image/michael2.bmp
# Predicted: hasudungan
#
# data/test_image/parida1.bmp
# Predicted: hasudungan
#
# data/test_image/parida2.bmp
# Predicted: hasudungan
#
# data/test_image/rosari1.bmp
# Predicted: hasudungan
#
# data/test_image/rosari2.bmp
# Predicted: hasudungan
#
# data/test_image/sonya1.bmp
# Predicted: mia
#
# data/test_image/sonya2.bmp
# Predicted: parida
#
# data/test_image/tahan1.bmp
# Predicted: parida
#
# data/test_image/tahan2.bmp
# Predicted: hasudungan
#
# data/test_image/yustina1.bmp
# ...
